# %%
import pandas as pd
import numpy as np 
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# %matplotlib inline  
import seaborn as sns
from sklearn.preprocessing import StandardScaler

import warnings
warnings.filterwarnings('ignore')

# %%
cards = pd.read_csv("/Users/briankalinowski/Desktop/Kaggle/Fraud_Analyis1/creditcard.csv")

# %%
cards.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
cards.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
cards.Class.value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
#Corralation matrix
sns.heatmap(cards.corr())

# %%
sns.countplot(cards.Class)

# %%
#Fraud or not fraud based on Time 

print ("Fraud Transactions")
print (cards.Time[cards.Class == 1].describe())
print "________________________"
print ("Not Fraud")
print (cards.Time[cards.Class == 0].describe())
# Out:
# Fraud Transactions
# count       492.000000
# mean      80746.806911
# std       47835.365138
# min         406.000000
# 25%       41241.500000
# 50%       75568.500000
# 75%      128483.000000
# max      170348.000000
# Name: Time, dtype: float64
# ________________________
# Not Fraud
# count    284315.000000
# mean      94838.202258
# std       47484.015786
# min           0.000000
# 25%       54230.000000
# 50%       84711.000000
# 75%      139333.000000
# max      172792.000000
# Name: Time, dtype: float64

# %%
#Based on the transaction ammount "Fraud"
print "Fraud"

print cards.Amount[cards.Class == 1].describe()

print "Not Fraud"

print cards.Amount[cards.Class == 0].describe()
# Out:
# Fraud
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64
# Not Fraud
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#Select only the anonymized "V" features.
v_features = cards.ix[:,1:29].columns
v_features
# Out:
# Index([u'V1', u'V2', u'V3', u'V4', u'V5', u'V6', u'V7', u'V8', u'V9', u'V10',
#        u'V11', u'V12', u'V13', u'V14', u'V15', u'V16', u'V17', u'V18', u'V19',
#        u'V20', u'V21', u'V22', u'V23', u'V24', u'V25', u'V26', u'V27', u'V28'],
#       dtype='object')

# %%
# Plots to show the distributinos of each feature between fraud and non-fraudlent transactions. 

plt.figure(figsize=(12,28*4))
gs = gridspec.GridSpec(28, 1)
for i, cn in enumerate(cards[v_features]):
    ax = plt.subplot(gs[i])
    sns.distplot(cards[cn][cards.Class == 1], bins=50)
    sns.distplot(cards[cn][cards.Class == 0], bins=50)
    ax.set_xlabel('')
    ax.set_title('histogram of feature: ' + str(cn))
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE

# %%
cards.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
train_cards, test_cards = train_test_split(cards, test_size=0.3)

# %%
X_train = cards.columns[0:30]
Y_train = cards.Class

# %%
model = LogisticRegression()
model.fit(train_cards[X_train],train_cards[Y_train])

# %%
predict = model.predict(test_cards[X_train])
accuracy = metrics.accuracy_score(predict)
